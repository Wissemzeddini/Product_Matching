# %%
import requests
import cv2
import pandas as pd
import csv
from bs4 import BeautifulSoup
import unicodedata
import mysql.connector
import ipynb
from ipynb.fs.full.SqlQuery import brandAdd
from ipynb.fs.full.SqlQuery import categorieAdd
from ipynb.fs.full.SqlQuery import AddProduct
from ipynb.fs.full.SqlQuery import getCagId
from ipynb.fs.full.SqlQuery import getBrandId
from ipynb.fs.full.SqlQuery import AddProductAttribut
from ipynb.fs.full.SqlQuery import AddLocalStoreProduct
from ipynb.fs.full.SqlQuery import Addlocalstors

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",
  database="python"
)

# %%
class links:  
    def __init__(self, name, link):  
        self.name = name  
        self.link = link 
def search_catg():
    list=[]
    web = requests.get('https://www.tunisianet.com.tn/').text
    parse = BeautifulSoup(web, 'lxml')
    for c in parse.find_all('div', class_ = 'wb-menu-row'):
        title=c.find_all('li', class_='menu-item item-header')
        for t in title:
            link=t.a['href']
            name=t.a.text
            list.append( links(name, link) )
    return list

# %%
def tunisianet_det(url):    
    web = requests.get(url).text
    parse = BeautifulSoup(web, 'lxml')
    try:
        brand_logo=parse.find('div', class_='product-manufacturer').a.img['src']
    except:
        brand_logo='None'
    feautre, titre='',''
    name= parse.find_all('dt', class_='name')
    value = parse.find_all('dd', class_='value')
    fich_list=[]
    for n in name:
        fich_tech={
            'label': n.text,
            'data': ''
            }
        fich_list.append(fich_tech)
    i=0
    for v in value:
        fich_list[i]['feature']=v.text
        i +=1
        
    article={
        'brand_logo':brand_logo,
        'fich_list':fich_list
    }
    return article

# %%
def priceConv(price):
    c=''
    for p in price:
        if(p.isdigit()):
            c=c+p
    return int(c)

# %%
i=0
j=0
n=''
list = search_catg()
supCatId=0
for l in list:
    link = l.link
    name = l.name
    web = requests.get(link).text
    parse = BeautifulSoup(web, 'lxml')
    categorieAdd(name, link, 17)
    supCatId=getCagId(name, 17)
    i=0
    j=0
    n=''
    nb= parse.find('div', class_='col-md-4 col-lg-4 col-xl-4 hidden-lg-down total-products text-xs-right').p.text
    for c in nb:
      if(c.isdigit()):
        n=n+c
    for x in range(1,30):
      if(x==1):
          link=link+'?page='+str(x)
      else:
          link=link[:-1]
          if(x>=10):
            link=link[:-1]
          link=link+str(x)
          text = requests.get(link)
          parse = BeautifulSoup(text.content, 'html.parser')
      art = parse.find_all('article', class_='product-miniature js-product-miniature col-xs-12 propadding')
      j=j+1
      print(f'{name}**************{i}:{j}*************{n}')
      if(int(n) > i):
        for a in art:
            i=i+1
            try:
              prod= a.find('h2', class_='h3 product-title').text
            except:
              prod='Unknown'
            try:
              img= a.find('img', class_='center-block img-responsive')['src']
            except:
              img='Undefined'
            try:
              brand= a.find('img', class_='img img-thumbnail manufacturer-logo')['alt']
            except:
              brand='Unknown'
            try:
                price= a.find('span', class_='price').text.replace(u'&nbsp;','')
                price=priceConv(price)
            except:
                price=0
            try:
              uid= a.find('span', class_='product-reference').text.replace('[','').replace(']','')
            except:
              uid='None'
            try:
              stock= a.find('span', class_='in-stock').text
            except:
              stock='Undefined'
            try:
              des = a.find('div', class_='listds').a.p.text
            except:
              des= 'None'
            art_link = a.find('h2', class_='h3 product-title').a.get('href')
            det=tunisianet_det(art_link)
            brandAdd(brand, det['brand_logo'], 17)
            supBrandId=getBrandId(brand ,17)
            prodId=AddProduct(prod, art_link, uid, des, price, stock, 17, supBrandId, supCatId, img)
            #print(price)
            if(det['fich_list']):
                AddProductAttribut(det['fich_list'], prodId)
      else:
        break
# Out:
# Data Base Categorie Duplication Error
#
# Ordinateur Portable**************0:1*************337
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ordinateur Portable**************24:2*************337
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ordinateur Portable**************48:3*************337
# Ordinateur Portable**************72:4*************337
# Ordinateur Portable**************96:5*************337
# Ordinateur Portable**************120:6*************337
# Ordinateur Portable**************144:7*************337
# Ordinateur Portable**************168:8*************337
# Ordinateur Portable**************192:9*************337
# Ordinateur Portable**************216:10*************337
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ordinateur Portable**************240:11*************337
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ordinateur Portable**************264:12*************337
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ordinateur Portable**************288:13*************337
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ordinateur Portable**************312:14*************337
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ordinateur Portable**************336:15*************337
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Add Product Attribut Fails
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ordinateur Portable**************360:16*************337
# Data Base Categorie Duplication Error
#
# Accessoires et Périphériques**************0:1*************762
# Accessoires et Périphériques**************24:2*************762
# Accessoires et Périphériques**************48:3*************762
# Accessoires et Périphériques**************72:4*************762
# Accessoires et Périphériques**************96:5*************762
# Accessoires et Périphériques**************120:6*************762
# Accessoires et Périphériques**************144:7*************762
# Accessoires et Périphériques**************168:8*************762
# Accessoires et Périphériques**************192:9*************762
# Accessoires et Périphériques**************216:10*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************240:11*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************264:12*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************288:13*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************312:14*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************336:15*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************360:16*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************384:17*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************408:18*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************432:19*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************456:20*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************480:21*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************504:22*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************528:23*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************552:24*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************576:25*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************600:26*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************624:27*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************648:28*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires et Périphériques**************672:29*************762
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ordinateur de Bureau**************0:1*************276
# Ordinateur de Bureau**************24:2*************276
# Ordinateur de Bureau**************48:3*************276
# Ordinateur de Bureau**************72:4*************276
# Ordinateur de Bureau**************96:5*************276
# Ordinateur de Bureau**************120:6*************276
# Ordinateur de Bureau**************144:7*************276
# Ordinateur de Bureau**************168:8*************276
# Ordinateur de Bureau**************192:9*************276
# Ordinateur de Bureau**************216:10*************276
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ordinateur de Bureau**************240:11*************276
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ordinateur de Bureau**************264:12*************276
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ordinateur de Bureau**************288:13*************276
# Logiciels**************0:1*************22
# Product Duplicate Error
# Logiciels**************22:2*************22
# Serveur informatique**************0:1*************96
# Serveur informatique**************24:2*************96
# Serveur informatique**************48:3*************96
# Serveur informatique**************72:4*************96
# Serveur informatique**************96:5*************96
# Onduleur**************0:1*************97
# Onduleur**************24:2*************97
# Onduleur**************48:3*************97
# Onduleur**************72:4*************97
# Onduleur**************96:5*************97
# Onduleur**************97:6*************97
# Composant  Informatique**************0:1*************404
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Composant  Informatique**************24:2*************404
# Product Duplicate Error
# Product Duplicate Error
# Composant  Informatique**************48:3*************404
# Composant  Informatique**************72:4*************404
# Composant  Informatique**************96:5*************404
# Composant  Informatique**************120:6*************404
# Composant  Informatique**************144:7*************404
# Composant  Informatique**************168:8*************404
# Composant  Informatique**************192:9*************404
# Composant  Informatique**************216:10*************404
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Composant  Informatique**************240:11*************404
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Composant  Informatique**************264:12*************404
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Composant  Informatique**************288:13*************404
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Composant  Informatique**************312:14*************404
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Composant  Informatique**************336:15*************404
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Composant  Informatique**************360:16*************404
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Composant  Informatique**************384:17*************404
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Composant  Informatique**************408:18*************404
# Téléphone Portable**************0:1*************35
# Téléphone Portable**************24:2*************35
# Téléphone Portable**************35:3*************35
# Smartphone**************0:1*************202
# Smartphone**************24:2*************202
# Smartphone**************48:3*************202
# Smartphone**************72:4*************202
# Smartphone**************96:5*************202
# Smartphone**************120:6*************202
# Smartphone**************144:7*************202
# Smartphone**************168:8*************202
# Smartphone**************192:9*************202
# Smartphone**************202:10*************202
# Téléphone Fixe**************0:1*************18
# Téléphone Fixe**************18:2*************18
# Tablette tactile**************0:1*************134
# Product Duplicate Error
# Tablette tactile**************24:2*************134
# Tablette tactile**************48:3*************134
# Tablette tactile**************72:4*************134
# Tablette tactile**************96:5*************134
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Tablette tactile**************120:6*************134
# Product Duplicate Error
# Product Duplicate Error
# Tablette tactile**************134:7*************134
# Accessoires Téléphones**************0:1*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************24:2*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************48:3*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************72:4*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************96:5*************590
# Accessoires Téléphones**************120:6*************590
# Product Duplicate Error
# Accessoires Téléphones**************144:7*************590
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************168:8*************590
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************192:9*************590
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************216:10*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************240:11*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************264:12*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************288:13*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************312:14*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************336:15*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************360:16*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************384:17*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************408:18*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************432:19*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************456:20*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************480:21*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************504:22*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************528:23*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires Téléphones**************552:24*************590
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# ...
# Matériel de sécurité**************80:5*************80
# Data Base Categorie Duplication Error
#
# Onduleur**************0:1*************97
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Onduleur**************24:2*************97
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Onduleur**************48:3*************97
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Onduleur**************72:4*************97
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Onduleur**************96:5*************97
# Product Duplicate Error
# Onduleur**************97:6*************97
# Matériel point de vente**************0:1*************106
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Matériel point de vente**************24:2*************106
# Product Duplicate Error
# Product Duplicate Error
# Matériel point de vente**************48:3*************106
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Matériel point de vente**************72:4*************106
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Matériel point de vente**************96:5*************106
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Matériel point de vente**************106:6*************106
# Data Base Categorie Duplication Error
#
# Papier**************0:1*************46
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Papier**************24:2*************46
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Papier**************46:3*************46
# Cadeaux**************0:1*************73
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Cadeaux**************24:2*************73
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Cadeaux**************48:3*************73
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Cadeaux**************72:4*************73
# Product Duplicate Error
# Cadeaux**************73:5*************73
# Ecriture & Correction**************0:1*************306
# Ecriture & Correction**************24:2*************306
# Ecriture & Correction**************48:3*************306
# Ecriture & Correction**************72:4*************306
# Ecriture & Correction**************96:5*************306
# Ecriture & Correction**************120:6*************306
# Ecriture & Correction**************144:7*************306
# Ecriture & Correction**************168:8*************306
# Ecriture & Correction**************192:9*************306
# Ecriture & Correction**************216:10*************306
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ecriture & Correction**************240:11*************306
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ecriture & Correction**************264:12*************306
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ecriture & Correction**************288:13*************306
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Ecriture & Correction**************312:14*************306
# Accessoires de bureau**************0:1*************82
# Accessoires de bureau**************24:2*************82
# Product Duplicate Error
# Accessoires de bureau**************48:3*************82
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Accessoires de bureau**************72:4*************82
# Product Duplicate Error
# Accessoires de bureau**************82:5*************82
# Classement & Archivage**************0:1*************159
# Classement & Archivage**************24:2*************159
# Classement & Archivage**************48:3*************159
# Classement & Archivage**************72:4*************159
# Classement & Archivage**************96:5*************159
# Classement & Archivage**************120:6*************159
# Product Duplicate Error
# Classement & Archivage**************144:7*************159
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Classement & Archivage**************159:8*************159
# Cahiers, blocs et feuilles**************0:1*************124
# Cahiers, blocs et feuilles**************24:2*************124
# Cahiers, blocs et feuilles**************48:3*************124
# Cahiers, blocs et feuilles**************72:4*************124
# Cahiers, blocs et feuilles**************96:5*************124
# Product Duplicate Error
# Cahiers, blocs et feuilles**************120:6*************124
# Product Duplicate Error
# Cahiers, blocs et feuilles**************124:7*************124
# Calculatrices**************0:1*************51
# Calculatrices**************24:2*************51
# Calculatrices**************48:3*************51
# Product Duplicate Error
# Product Duplicate Error
# Calculatrices**************51:4*************51
# Nettoyage**************0:1*************19
# Nettoyage**************19:2*************19
# Décoration**************0:1*************15
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Décoration**************15:2*************15
# Bagageries**************0:1*************10
# Bagageries**************10:2*************10
# Adhésifs, Agrafage & Découpe**************0:1*************187
# Adhésifs, Agrafage & Découpe**************24:2*************187
# Adhésifs, Agrafage & Découpe**************48:3*************187
# Product Duplicate Error
# Adhésifs, Agrafage & Découpe**************72:4*************187
# Adhésifs, Agrafage & Découpe**************96:5*************187
# Adhésifs, Agrafage & Découpe**************120:6*************187
# Adhésifs, Agrafage & Découpe**************144:7*************187
# Adhésifs, Agrafage & Découpe**************168:8*************187
# Product Duplicate Error
# Product Duplicate Error
# Adhésifs, Agrafage & Découpe**************187:9*************187
# Tableaux**************0:1*************58
# Tableaux**************24:2*************58
# Tableaux**************48:3*************58
# Tableaux**************58:4*************58
# Réseau**************0:1*************132
# Product Duplicate Error
# Réseau**************24:2*************132
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Réseau**************48:3*************132
# Réseau**************72:4*************132
# Réseau**************96:5*************132
# Réseau**************120:6*************132
# Réseau**************132:7*************132
# Câbles et Connectiques**************0:1*************248
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Câbles et Connectiques**************24:2*************248
# Câbles et Connectiques**************48:3*************248
# Câbles et Connectiques**************72:4*************248
# Product Duplicate Error
# Product Duplicate Error
# Câbles et Connectiques**************96:5*************248
# Câbles et Connectiques**************120:6*************248
# Câbles et Connectiques**************144:7*************248
# Câbles et Connectiques**************168:8*************248
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Câbles et Connectiques**************192:9*************248
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Câbles et Connectiques**************216:10*************248
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Câbles et Connectiques**************240:11*************248
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Câbles et Connectiques**************264:12*************248
# Coffrets et Accessoires**************0:1*************25
# Coffrets et Accessoires**************24:2*************25
# Coffrets et Accessoires**************25:3*************25
