# %%
import requests
import cv2
import pandas as pd
import csv
from bs4 import BeautifulSoup
import mysql.connector
import ipynb
from ipynb.fs.full.SqlQuery import brandAdd
from ipynb.fs.full.SqlQuery import categorieAdd
from ipynb.fs.full.SqlQuery import AddProduct
from ipynb.fs.full.SqlQuery import getCagId
from ipynb.fs.full.SqlQuery import getBrandId
from ipynb.fs.full.SqlQuery import AddProductAttribut

# %%
# mydb = mysql.connector.connect(
#   host="localhost",
#   user="root",
#   password="",
#   database="python"
# )

# %%
def bestbuy_links():
    list=[]
    web = requests.get('https://bestbuytunisie.com/')
    parse = BeautifulSoup(web.content, 'html.parser')
    menu= parse.find('ul', id='menu-all-departments-menu-1').find_all('a')
    for m in menu:
        info= m.text
        link=m.get('href')
        if link != '#':
            bestbuy_dict={
                'info':info,
                'link':link
              }
            list.append(bestbuy_dict)
    return list

# %%
def bestbuy_det(url):
    text = requests.get(url).text
    soup = BeautifulSoup(text, 'lxml')
    try:
        name= soup.find('h1', class_ ='product_title entry-title').text
    except:
        name = 'Unknown'
    try:
        brand = soup.find('table', class_='woocommerce-product-attributes shop_attributes').tr.td.text.replace(u'\n','')
    except:
        brand = 'Unknown'
    try:    
        des = soup.find('div', class_ = 'woocommerce-product-details__short-description').p.text.replace('–','').strip()
    except:
        des='None'
    label,data,list='','',[]
    try:
        table= soup.find('table', class_='woocommerce-product-attributes shop_attributes').find_all('tr')
        for t in table:
            label=t.th.text.strip()
            data=t.td.text.strip()
            dict={
                'label':label,
                'data':data
            }
            list.append(dict)
    except:
        list=[]
    article ={
          'name':name,
          'brand': brand,
          'des': des,
          'fich_tech':list
      }
    return article

# %%
def priceConv(price):
    c=''
    for p in price:
        if(p.isdigit()):
            c=c+p
    return int(c)

# %%
def next_url(url, x):
    if(x == 1):
        url=url+'page/'+str(x)
    else:
        url=url[:-1]
        if(x>10):
            url=url[:-1]
        url=url+str(x)
    web = requests.get(url)
    parse = BeautifulSoup(web.content, 'html.parser')
    if(parse.find('div', class_='info-404')):
        return False  
  
    return url

# %%
# mycursor = mydb.cursor()
list = bestbuy_links()
for l in list:
    info = l['info']
    link = l['link']
    categorieAdd(info, link, 25)
    supCatId=getCagId(info,25)
    for x in range(1, 30):
        link= next_url(link,x)
        print(link)
        if(not(link == False)):
            web = requests.get(link)
            parse = BeautifulSoup(web.content, 'html.parser')
            card= parse.find('ul', class_='products columns-4 columns__wide--5').find_all('li')
            for c in card:
                try:
                    stock= c.find('span', class_='wapl-label-text').text
                except:
                    stock= 'non disponible'
                try:
                    img= c.find('img', class_='attachment-woocommerce_thumbnail')['data-lazy-src']
                except:
                    img='None'
                try:
                    price= c.find('span', class_ ='price').text.replace(u'\xa0','')
                    price=priceConv(price)
                except:
                    price=0
                try:
                    det_link= c.find('a', class_='woocommerce-LoopProduct-link woocommerce-loop-product__link')['href']
                    det=bestbuy_det(det_link)
                except:
                    det_link='None'
                brandAdd(det['brand'], 'None', 25)
                supBrandId=getBrandId(det['brand'], 25)
                prodId=AddProduct(det['name'], det_link, 'None', det['des'], price, stock, 25, supBrandId, supCatId, img)
                if(det['fich_tech']):
                    AddProductAttribut(det['fich_tech'], prodId)
               
        else:
            break
# Out:
# https://bestbuytunisie.com/categorie-produit/informatique/pc/pc-portable/page/1
# https://bestbuytunisie.com/categorie-produit/informatique/pc/pc-portable/page/2
# https://bestbuytunisie.com/categorie-produit/informatique/pc/pc-portable/page/3
# https://bestbuytunisie.com/categorie-produit/informatique/pc/pc-portable/page/4
# https://bestbuytunisie.com/categorie-produit/informatique/pc/pc-portable/page/5
# False
# https://bestbuytunisie.com/categorie-produit/informatique/pc/pc-portable-gamer-en-tunisie/page/1
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# https://bestbuytunisie.com/categorie-produit/informatique/pc/pc-portable-gamer-en-tunisie/page/2
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# False
# https://bestbuytunisie.com/categorie-produit/informatique/pc/mac/page/1
# False
# https://bestbuytunisie.com/categorie-produit/logiciel/antivirus/page/1
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# False
# https://bestbuytunisie.com/categorie-produit/logiciel/suite-bureautique/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/ecran/page/1
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/ecran/page/2
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/ecran/page/3
# False
# https://bestbuytunisie.com/categorie-produit/informatique/pc/pc-de-bureau/page/1
# False
# https://bestbuytunisie.com/categorie-produit/gaming/pc-gamer/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/pc/pc-tout-en-un/page/1
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# False
# https://bestbuytunisie.com/categorie-produit/informatique/ordinateur-de-bureau/imac/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/composants-pc/processeur-pc/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/composants-pc/barrettes-memoire-pc/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/composants-pc/ventilateur-pc/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/composants-pc/carte-mere-pc/page/1
# https://bestbuytunisie.com/categorie-produit/informatique/composants-pc/carte-mere-pc/page/2
# https://bestbuytunisie.com/categorie-produit/informatique/composants-pc/carte-mere-pc/page/3
# https://bestbuytunisie.com/categorie-produit/informatique/composants-pc/carte-mere-pc/page/4
# False
# https://bestbuytunisie.com/categorie-produit/informatique/composants-pc/carte-graphique-pc/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/composants-pc/carte-son-pc/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/composants-pc/bloc-dalimentation-pc/page/1
# Product Duplicate Error
# False
# https://bestbuytunisie.com/categorie-produit/informatique/stockage/disque-dur-ssd/page/1
# https://bestbuytunisie.com/categorie-produit/informatique/stockage/disque-dur-ssd/page/2
# False
# https://bestbuytunisie.com/categorie-produit/informatique/composants-pc/chargeur-pc-portable/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/clavier-souris/page/1
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/clavier-souris/page/2
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/clavier-souris/page/3
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/clavier-souris/page/4
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/clavier-souris/page/5
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/clavier-souris/page/6
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/clavier-souris/page/7
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/clavier-souris/page/8
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/clavier-souris/page/9
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/clavier-souris/page/10
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/clavier-souris/page/11
# False
# https://bestbuytunisie.com/categorie-produit/multimedia/son-numerique/casque-kit/page/1
# https://bestbuytunisie.com/categorie-produit/multimedia/son-numerique/casque-kit/page/2
# https://bestbuytunisie.com/categorie-produit/multimedia/son-numerique/casque-kit/page/3
# https://bestbuytunisie.com/categorie-produit/multimedia/son-numerique/casque-kit/page/4
# Product Duplicate Error
# https://bestbuytunisie.com/categorie-produit/multimedia/son-numerique/casque-kit/page/5
# https://bestbuytunisie.com/categorie-produit/multimedia/son-numerique/casque-kit/page/6
# False
# https://bestbuytunisie.com/categorie-produit/informatique/accessoires/sacs-sacoches/page/1
# https://bestbuytunisie.com/categorie-produit/informatique/accessoires/sacs-sacoches/page/2
# False
# https://bestbuytunisie.com/categorie-produit/gaming/accessoires-gaming/manette-de-jeu/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/refroidisseurs/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/hub-usb/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/graveurs-et-lecteurs/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/support-ecran/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/tapis-de-souris/page/1
# Product Duplicate Error
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/tapis-de-souris/page/2
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# https://bestbuytunisie.com/categorie-produit/informatique/peripherique/tapis-de-souris/page/3
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# False
# https://bestbuytunisie.com/categorie-produit/informatique/composants-pc/clavier-pc-portable/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/serveurs/serveurs-serveurs/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/stockage/disque-dur-interne/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/stockage/disque-dur-externe/page/1
# False
# Data Base Categorie Duplication Error
#
# https://bestbuytunisie.com/categorie-produit/informatique/stockage/disque-dur-ssd/page/1
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# https://bestbuytunisie.com/categorie-produit/informatique/stockage/disque-dur-ssd/page/2
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# False
# https://bestbuytunisie.com/categorie-produit/informatique/stockage/carte-memoire/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/stockage/cle-usb/page/1
# https://bestbuytunisie.com/categorie-produit/informatique/stockage/cle-usb/page/2
# False
# https://bestbuytunisie.com/categorie-produit/informatique/stockage/accessoires-de-stockage/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/onduleur/onduleur-in-line/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/onduleur/onduleur-on-line/page/1
# False
# https://bestbuytunisie.com/categorie-produit/informatique/onduleur/onduleur-off-line/page/1
# False
# Data Base Categorie Duplication Error
#
# https://bestbuytunisie.com/categorie-produit/informatique/pc/pc-portable-gamer-en-tunisie/page/1
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# https://bestbuytunisie.com/categorie-produit/informatique/pc/pc-portable-gamer-en-tunisie/page/2
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# False
# Data Base Categorie Duplication Error
#
# https://bestbuytunisie.com/categorie-produit/gaming/pc-gamer/page/1
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# False
# https://bestbuytunisie.com/categorie-produit/gaming/peripheriques-et-accessoires-gamers/ecrans-gamer/page/1
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# https://bestbuytunisie.com/categorie-produit/gaming/peripheriques-et-accessoires-gamers/ecrans-gamer/page/2
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# False
# https://bestbuytunisie.com/categorie-produit/gaming/console-de-jeux/ps4/page/1
# False
# https://bestbuytunisie.com/categorie-produit/gaming/console-de-jeux/ps5/page/1
# False
# https://bestbuytunisie.com/categorie-produit/gaming/console-de-jeux/my-arcade/page/1
# False
# https://bestbuytunisie.com/categorie-produit/gaming/accessoires-consoles/xbox-1/page/1
# False
# https://bestbuytunisie.com/categorie-produit/gaming/accessoires-gaming/souris/page/1
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# https://bestbuytunisie.com/categorie-produit/gaming/accessoires-gaming/souris/page/2
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
# Product Duplicate Error
